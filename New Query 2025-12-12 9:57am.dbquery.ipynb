-- %%
WITH converted_sql_0 AS (
  SELECT
    *
  FROM
    demo.dlt_cdc_pipeline.customers
  WHERE
    lower(c_name) = 'scott johnson'
)
SELECT
  *
FROM
  converted_sql_0;

/*
nodes:
  converted_sql_0:
    description:
      text: Filter to customer named Scott Johnson.
      hash: 29b94792
*/
